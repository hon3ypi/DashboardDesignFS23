# %%
pip install dash
pip install plotly
pip install pandas

# %%
#Aufgabe 3a
import pandas as pd
import plotly.express as px

#path
path = "C:\\Users\\wanda\\01_Dashboard_Design\\Goal5.5.2_csv.csv"

import dash
from dash import dcc, html
from dash.dependencies import Input, Output

datafile = pd.read_csv(path)

print(datafile.head)

# %%
#Aufgabenblatt 2 als Gesamtes

#Import
import pandas as pd
import plotly.express as px
import numpy as np
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

#Dateipfad
path = "C:\\Users\\wanda\\01_Dashboard_Design\\Goal5.5.2_csv.csv"

#Daten aus CSV-Datei laden
datafile = pd.read_csv(path)

#Balkendiagramm erstellen
#fig = px.bar(datafile, x='GeoAreaName', y='Value')

#Filtern nach Schweiz
swiss_data = datafile[datafile['GeoAreaName'] == 'Switzerland']

#Balkendiagramm erstellen
#fig = px.bar(swiss_data, x='TimePeriod', y='Value', color='GeoAreaName')

#Alles
#fig = px.bar(datafile, x='TimePeriod', y='Value', color='GeoAreaName')

#fig = px.bar(swiss_data, x='TimePeriod', y='Value', color='GeoAreaName')

fig = px.bar(swiss_data, x='TimePeriod', y='Value', color='GeoAreaName', facet_col='GeoAreaName', facet_col_wrap=2)
fig.show()



app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Proportion of women in managerial positions", style={'text-align': 'center'}),
    html.H4("Numbers and facts about women in managerial positions in the world", style={'text-align': 'center'}),
    dcc.Graph(figure=fig)
])

if __name__ == '__main__':
    app.run_server(debug=False)

# %%
#Aufgabenblatt 2 als Gesamtes

#Import
import pandas as pd
import plotly.express as px
import numpy as np
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

#Mit angepasster Datensatz
#Dateipfad
path = "C:\\Users\\wanda\\01_Dashboard_Design\\newDataset.csv"

#Daten aus CSV-Datei laden
datafile = pd.read_csv(path)

#Array mit Länder
countries = ['Switzerland', 'Germany', 'France', 'Austria', 'Italy']

# Daten für die ausgewählten Länder filtern
filteredData = datafile.query('GeoAreaName in @countries')

#Balkendiagramm erstellen
#fig = px.bar(datafile, x="Year", y="Value", color="GeoAreaName", facet_col="GeoAreaName", facet_col_wrap=148)
#fig.show()

#fig = px.bar(filteredData, x='Year', y='Value', color='GeoAreaName', facet_col='GeoAreaName')
fig = px.histogram(datafile, x="Year", y="Value", color='GeoAreaName', barmode='group')
fig.show()



app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Proportion of women in managerial positions", style={'text-align': 'center'}),
    html.H4("Numbers and facts about women in managerial positions in the world", style={'text-align': 'center'}),
    dcc.Graph(figure=fig)
])

if __name__ == '__main__':
    app.run_server(debug=False)

# %%
#Aufgabenblatt 2 als Gesamtes

#Import
import pandas as pd
import plotly.express as px
import numpy as np
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

#Dateipfad
path = "C:\\Users\\wanda\\01_Dashboard_Design\\Goal5.5.2_csv.csv"

#Daten aus CSV-Datei laden
datafile = pd.read_csv(path)

#Balkendiagramm erstellen
#fig = px.bar(datafile, x='GeoAreaName', y='Value')

countries = ['Switzerland', 'Germany', 'France', 'Austria', 'Italy']
#Filtern nach Länder
filteredData = datafile.query('GeoAreaName in @countries')


fig = px.bar(filteredData, x='TimePeriod', y='Value', color='GeoAreaName', facet_col='GeoAreaName', facet_col_wrap=2)
fig.show()



app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Proportion of women in managerial positions", style={'text-align': 'center'}),
    html.H4("Numbers and facts about women in managerial positions in the world", style={'text-align': 'center'}),
    dcc.Graph(figure=fig)
])

if __name__ == '__main__':
    app.run_server(debug=False)

# %%
#Aufgabe 3b
import pandas as pd
import plotly.express as px

#path
path = "C:\\Users\\wanda\\01_Dashboard_Design\\Goal5.5.2_csv.csv"

import dash
from dash import dcc, html
from dash.dependencies import Input, Output


datafile = pd.read_csv(path)

swiss_data = datafile[datafile['GeoAreaName'] == 'Switzerland']
pos_data = datafile[datafile['SeriesDescription'] == 'Proportion of women in managerial positions (%)']  

#Array mit Länder
countries = ['Switzerland', 'Germany', 'France', 'Austria', 'Italy']
years = [2010, 2011, 2012, 2013, 2014, 2015]
#Daten filtern
filteredData = datafile.query('GeoAreaName in @countries')
filtYear = datafile.query('TimePeriod in @years')

filtComb = datafile.query('GeoAreaName in @countries & TimePeriod in @years')


#print(swiss_data)
#print(filteredData)
#print(pos_data)
print(filtComb)

# %%
#Aufgabenblatt 2 als Gesamtes

#Import
import pandas as pd
import plotly.express as px
import numpy as np
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

#Dateipfad
path = "C:\\Users\\wanda\\01_Dashboard_Design\\Goal5.5.2_csv.csv"

#Daten aus CSV-Datei laden
datafile = pd.read_csv(path)

#Balkendiagramm erstellen
#fig = px.bar(datafile, x='GeoAreaName', y='Value')

countries = ['Switzerland', 'Germany', 'France', 'Austria', 'Italy']
years = [2018]
#Filtern nach Länder
filteredData = datafile.query('GeoAreaName in @countries & TimePeriod in @years')


fig = px.bar(datafile, x='TimePeriod', y='Value', color='GeoAreaName')
fig.show()



app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Proportion of women in managerial positions", style={'text-align': 'center'}),
    html.H4("Numbers and facts about women in managerial positions in the world", style={'text-align': 'center'}),
    dcc.Graph(figure=fig)
])

if __name__ == '__main__':
    app.run_server(debug=False)
