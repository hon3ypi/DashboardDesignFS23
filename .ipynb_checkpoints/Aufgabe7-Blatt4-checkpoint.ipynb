# %%
#Aufgabe 7a

import math
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import dash
from dash import Dash, dcc, html, Input, Output
import dash_bootstrap_components as dbc
from sklearn.datasets import make_blobs
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

df = pd.DataFrame({'y': np.random.normal(loc=0, scale=10, size=1000),
                   'x': np.random.normal(loc=10, scale=2, size=1000)})


COLORS = {'0': "red", '1': "blue", '2': "grey"}

X, y = make_blobs(n_samples=100, centers=3, n_features=2, random_state=0)

cluster_df = pd.DataFrame(data=X, columns=["X", "Y"])
cluster_df['cluster'] = [str(i) for i in y]

app.layout = html.Div([
    html.Div([html.H1("Dashboard 4")], className="header"),
    html.Div([
        dcc.Tabs(id="tabs", children=[
            # TAB 1
            dcc.Tab(label='Tab One', id="tab_1_graphs", children=[html.Div([
                dbc.Row([
                    dbc.Col([dcc.Dropdown(options=[{'label': 'Red', 'value': 'red'},
                                                   {'label': 'Green', 'value': 'green'},
                                                   {'label': 'Blue', 'value': 'blue'}],
                                          value='red', id='color', multi=False)], width=6),
                    dbc.Col([dcc.Slider(min=math.floor(df['y'].min()), max=math.ceil(df['y'].max()), id="min_value")],
                            width=6)
                ]),
                dbc.Row([
                    dbc.Col([dcc.Graph(id="graph_1")], width=6),
                    dbc.Col([dcc.Graph(id="graph_2")], width=6)
                ])
            ], className="tab_content")]),
            # TAB 2
            # Hierzu betrachten wir das Streudiagramm, welches trivariate Daten anzeigen kann (in den visuellen Variablen Position (x-, y-Achse) und Farbe)
            dcc.Tab(label='Tab Two', id="tab_2_graphs", children=[html.Div([
                dbc.Row([
                    dbc.Col([dcc.Graph(id="graph_3")], width=8),
                    dbc.Col([dcc.Graph(id="graph_4")], width=4),
                    dbc.Col([dcc.Graph(id="ex7a_graph")])
                ])
            ], className="tab_content")])
        ])
    ], className="content")
])


@app.callback(Output("graph_1", "figure"), Input("color", "value"))
def update_graph_1(dropdown_value_color):
    fig = px.histogram(df, x="y", color_discrete_sequence=[dropdown_value_color])
    fig.update_layout(template="plotly_white")
    return fig


@app.callback(Output("graph_2", "figure"), Input("min_value", "value"))
def update_graph_2(min_value):
    if min_value:
        dff = df[df['y'] > min_value]
    else:
        dff = df
    fig = px.scatter(dff, x='x', y='y')
    fig.update_layout(template="plotly_white")
    return fig


@app.callback(Output("graph_3", "figure"), Output("graph_4", "figure"), Input("graph_3", "relayoutData"))
def update_graph_3_and_4(selected_data):
    if selected_data is None or (isinstance(selected_data, dict) and 'xaxis.range[0]' not in selected_data):
        cluster_dff = cluster_df
    else:
        cluster_dff = cluster_df[(cluster_df['X'] >= selected_data.get('xaxis.range[0]')) &
                                 (cluster_df['X'] <= selected_data.get('xaxis.range[1]')) &
                                 (cluster_df['Y'] >= selected_data.get('yaxis.range[0]')) &
                                 (cluster_df['Y'] <= selected_data.get('yaxis.range[1]'))]

    fig3 = px.scatter(cluster_dff, x="X", y="Y", color="cluster", color_discrete_map=COLORS,
                      category_orders={"cluster": ["0", "1", "2"]}, height=750)
    fig3.update_layout(template="plotly_white", coloraxis_showscale=False)
    fig3.update_traces(marker=dict(size=8))

    group_counts = cluster_dff['cluster'].value_counts().reset_index()
    group_counts.columns = ['cluster', 'count']

    fig4 = go.Figure(data=[go.Bar(x=group_counts['cluster'], y=group_counts['count'],
                                 marker_color=[COLORS.get(i) for i in group_counts['cluster']])])
    fig4.update_layout(height=750, template="plotly_white", title="<b>Counts per cluster</b>", xaxis_title="cluster",
                       title_font_size=25)
    return fig3, fig4

#Modifizieren Sie den Dashboard Code auf eine Art, so dass das Streudiagramm nach dem Auswählen 
#der Datenpunkte ein neues Streudiagramm erzeugt, welches nur die selektierten Datenpunkte zeigt

@app.callback(Output("ex7a_graph", "figure"), Input("graph_3", "relayoutData"))
def update_ex7a_graph(selected_data):
    if selected_data is None or (isinstance(selected_data, dict) and 'xaxis.range[0]' not in selected_data):
        return go.Figure()

    selected_cluster_dff = cluster_df[(cluster_df['X'] >= selected_data.get('xaxis.range[0]')) &
                                      (cluster_df['X'] <= selected_data.get('xaxis.range[1]')) &
                                      (cluster_df['Y'] >= selected_data.get('yaxis.range[0]')) &
                                      (cluster_df['Y'] <= selected_data.get('yaxis.range[1]'))]

    fig = px.scatter(selected_cluster_dff, x="X", y="Y", color="cluster", color_discrete_map=COLORS,
                     category_orders={"cluster": ["0", "1", "2"]}, height=400)
    fig.update_layout(template="plotly_white", coloraxis_showscale=False)
    fig.update_traces(marker=dict(size=8))

    return fig


if __name__ == '__main__':
    app.run_server(debug=False)

# %%
"""" 
import math
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import dash
from dash import Dash, dcc, html, Input, Output
import dash_bootstrap_components as dbc
from sklearn.datasets import make_blobs

app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

df = pd.DataFrame({'y': np.random.normal(loc=0, scale=10, size=1000),
                   'x': np.random.normal(loc=10, scale=2, size=1000)})


COLORS = {'0': "red", '1': "blue", '2': "grey"}

X, y = make_blobs(n_samples=100, centers=3, n_features=2, random_state=0)

cluster_df = pd.DataFrame(data=X, columns=["X", "Y"])
cluster_df['cluster'] = [str(i) for i in y]

app.layout = html.Div([
    html.Div([html.H1("Dashboard 4")], className="header"),
    html.Div([
        dcc.Tabs(id="tabs", children=[
            #TAB 1
            dcc.Tab(label='Tab One', id="tab_1_graphs", children=[html.Div([
                dbc.Row([
                    dbc.Col([dcc.Dropdown(options=[{'label': 'Red', 'value': 'red'},
                                                   {'label': 'Green', 'value': 'green'},
                                                   {'label': 'Blue', 'value': 'blue'}],
                                          value='red', id='color', multi=False)], width=6),
                    dbc.Col([dcc.Slider(min=math.floor(df['y'].min()), max=math.ceil(df['y'].max()), id="min_value")], width=6)
                ]),
                dbc.Row([
                    dbc.Col([dcc.Graph(id="graph_1")], width=6),
                    dbc.Col([dcc.Graph(id="graph_2")], width=6)
                ])
            ], className="tab_content")]),
            #TAB 2
            # Hierzu betrachten wir das Streudiagramm, welches trivariate Daten anzeigen kann (in den visuellen Variablen Position (x-, y-Achse) und Farbe)
            dcc.Tab(label='Tab Two', id="tab_2_graphs", children=[html.Div([
                dbc.Row([
                    dbc.Col([dcc.Graph(id="graph_3")], width=8),
                    dbc.Col([dcc.Graph(id="graph_4")], width=4)
                ])
            ], className="tab_content")])
        ])
    ], className="content")
])


@app.callback(Output("graph_1", "figure"), Input("color", "value"))
def update_graph_1(dropdown_value_color):
    fig = px.histogram(df, x="y", color_discrete_sequence=[dropdown_value_color])
    fig.update_layout(template="plotly_white")
    return fig

@app.callback(Output("graph_2", "figure"), Input("min_value", "value"))
def update_graph_2(min_value):
    if min_value:
        dff = df[df['y'] > min_value]
    else:
        dff = df
    fig = px.scatter(dff, x='x', y='y')
    fig.update_layout(template="plotly_white")
    return fig

@app.callback(Output("graph_3", "figure"), Output("graph_4", "figure"), Input("graph_3", "relayoutData"))
def update_graph_3_and_4(selected_data):
    if selected_data is None or (isinstance(selected_data, dict) and 'xaxis.range[0]' not in selected_data):
        cluster_dff = cluster_df
    else:
        cluster_dff = cluster_df[(cluster_df['X'] >= selected_data.get('xaxis.range[0]')) &
                                 (cluster_df['X'] <= selected_data.get('xaxis.range[1]')) &
                                 (cluster_df['Y'] >= selected_data.get('yaxis.range[0]')) &
                                 (cluster_df['Y'] <= selected_data.get('yaxis.range[1]'))]

    fig3 = px.scatter(cluster_dff, x="X", y="Y", color="cluster", color_discrete_map=COLORS, category_orders={"cluster": ["0", "1", "2"]}, height=750)
    fig3.update_layout(template="plotly_white", coloraxis_showscale=False)
    fig3.update_traces(marker=dict(size=8))

    group_counts = cluster_dff['cluster'].value_counts().reset_index()
    group_counts.columns = ['cluster', 'count']

    fig4 = go.Figure(data=[go.Bar(x=group_counts['cluster'], y=group_counts['count'], marker_color=[COLORS.get(i) for i in group_counts['cluster']])])
    fig4.update_layout(height=750, template="plotly_white", title="<b>Counts per cluster</b>", xaxis_title="cluster", title_font_size=25)
    return fig3, fig4

#Modifizieren Sie den Dashboard Code auf eine Art, so dass das Streudiagramm nach dem Auswählen 
#der Datenpunkte ein neues Streudiagramm erzeugt, welches nur die selektierten Datenpunkte zeigt


if __name__ == '__main__':
    app.run_server(debug=False)
"""

# %%
#Aufgabe 7b
import math
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import dash
from dash import Dash, dcc, html, Input, Output
import dash_bootstrap_components as dbc
from sklearn.datasets import make_blobs

app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

df = pd.DataFrame({'y': np.random.normal(loc=0, scale=10, size=1000),
                   'x': np.random.normal(loc=10, scale=2, size=1000)})

COLORS = {'0': "red", '1': "blue", '2': "grey"}

X, y = make_blobs(n_samples=100, centers=3, n_features=2, random_state=0)

cluster_df = pd.DataFrame(data=X, columns=["X", "Y"])
cluster_df['cluster'] = [str(i) for i in y]

app.layout = html.Div([
    html.Div([html.H1("Dashboard 4")], className="header"),
    html.Div([
        dcc.Tabs(id="tabs", children=[
            # TAB 1
            dcc.Tab(label='Tab One', id="tab_1_graphs", children=[html.Div([
                dbc.Row([
                    dbc.Col([dcc.Dropdown(options=[{'label': 'Red', 'value': 'red'},
                                                   {'label': 'Green', 'value': 'green'},
                                                   {'label': 'Blue', 'value': 'blue'}],
                                          value='red', id='color', multi=False)], width=6)
                ]),
                dbc.Row([
                    dbc.Col([dcc.Graph(id="graph_1")], width=6),
                    dbc.Col([dcc.Graph(id="graph_2")], width=6)
                ])
            ], className="tab_content")]),
            # TAB 2
            dcc.Tab(label='Tab Two', id="tab_2_graphs", children=[html.Div([
                dbc.Row([
                    # Slider
                    dbc.Col([html.Label("Anzahl der Cluster:"),
                             dcc.Slider(min=1, max=3, step=1, value=3, id="cluster_slider")], width=12),
                ]),
                dbc.Row([
                    dbc.Col([dcc.Graph(id="graph_3")], width=8),
                    dbc.Col([dcc.Graph(id="graph_4")], width=4),
                ]),
                dbc.Row([
                    dbc.Col([dcc.Graph(id="ex7a_graph")], width=12)
                ])
            ], className="tab_content")])
        ])
    ], className="content")
])


@app.callback(Output("graph_1", "figure"), Input("color", "value"))
def update_graph_1(dropdown_value_color):
    fig = px.histogram(df, x="y", color_discrete_sequence=[dropdown_value_color])
    fig.update_layout(template="plotly_white")
    return fig


@app.callback(Output("graph_2", "figure"), Input("color", "value"))
def update_graph_2(dropdown_value_color):
    fig = px.scatter(df, x='x', y='y', color_discrete_sequence=[dropdown_value_color])
    fig.update_layout(template="plotly_white")
    return fig


@app.callback(Output("graph_3", "figure"), Output("graph_4", "figure"),
              Input("graph_3", "relayoutData"), Input("cluster_slider", "value"))
def update_graph_3_and_4(selected_data, cluster_value):
    if selected_data is None or (isinstance(selected_data, dict) and 'xaxis.range[0]' not in selected_data):
        cluster_dff = cluster_df[cluster_df['cluster'].isin([str(i) for i in range(cluster_value)])]
    else:
        cluster_dff = cluster_df[(cluster_df['X'] >= selected_data.get('xaxis.range[0]')) &
                                 (cluster_df['X'] <= selected_data.get('xaxis.range[1]')) &
                                 (cluster_df['Y'] >= selected_data.get('yaxis.range[0]')) &
                                 (cluster_df['Y'] <= selected_data.get('yaxis.range[1]')) &
                                 cluster_df['cluster'].isin([str(i) for i in range(cluster_value)])]

    fig3 = px.scatter(cluster_dff, x="X", y="Y", color="cluster", color_discrete_map=COLORS,
                      category_orders={"cluster": [str(i) for i in range(cluster_value)]}, height=750)
    fig3.update_layout(template="plotly_white", coloraxis_showscale=False)
    fig3.update_traces(marker=dict(size=8))

    group_counts = cluster_dff['cluster'].value_counts().reset_index()
    group_counts.columns = ['cluster', 'count']

    fig4 = go.Figure(data=[go.Bar(x=group_counts['cluster'], y=group_counts['count'],
                                 marker_color=[COLORS.get(i) for i in group_counts['cluster']])])
    fig4.update_layout(height=750, template="plotly_white", title="<b>Counts per cluster</b>", xaxis_title="cluster",
                       title_font_size=25)
    return fig3, fig4

#Modifizieren Sie den Dashboard Code auf eine Art, so dass das Streudiagramm nach dem Auswählen 
#der Datenpunkte ein neues Streudiagramm erzeugt, welches nur die selektierten Datenpunkte zeigt

@app.callback(Output("ex7a_graph", "figure"), Input("graph_3", "relayoutData"))
def update_ex7a_graph(selected_data):
    if selected_data is None or (isinstance(selected_data, dict) and 'xaxis.range[0]' not in selected_data):
        return go.Figure()

    selected_cluster_dff = cluster_df[(cluster_df['X'] >= selected_data.get('xaxis.range[0]')) &
                                      (cluster_df['X'] <= selected_data.get('xaxis.range[1]')) &
                                      (cluster_df['Y'] >= selected_data.get('yaxis.range[0]')) &
                                      (cluster_df['Y'] <= selected_data.get('yaxis.range[1]'))]

    fig = px.scatter(selected_cluster_dff, x="X", y="Y", color="cluster", color_discrete_map=COLORS,
                     category_orders={"cluster": ["0", "1", "2"]}, height=400)
    fig.update_layout(template="plotly_white", coloraxis_showscale=False)
    fig.update_traces(marker=dict(size=8))

    return fig

if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [14/Jun/2023 15:39:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:39:57] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:39:57] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:39:57] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:39:57] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:39:57] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:39:57] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-06-14 15:39:57,153] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\wanda\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\wanda\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\wanda\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\wanda\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\wanda\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\wanda\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\wanda\anaconda3\lib\site-packages\dash\dash.py", line 1249, in dispatch
#     ctx.run(
#   File "C:\Users\wanda\anaconda3\lib\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-1941c05c56cc>", line 69, in update_graph_2
#     fig = px.scatter(df, x='x', y='y', color_discrete_sequence=[dropdown_value_color])
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\express\_chart_types.py", line 66, in scatter
#     return make_figure(args=locals(), constructor=go.Scatter)
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\express\_core.py", line 1994, in make_figure
#     apply_default_cascade(args)
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\express\_core.py", line 947, in apply_default_cascade
#     args["symbol_sequence"] = [
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\express\_core.py", line 948, in <listcomp>
#     scatter.marker.symbol for scatter in args["template"].data.scatter
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\graph_objs\scatter\_marker.py", line 1191, in symbol
#     return self["symbol"]
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\basedatatypes.py", line 4724, in __getitem__
#     elif self._props is not None and prop in self._props:
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\basedatatypes.py", line 4419, in _props
#     return self.parent._get_child_props(self)
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\basedatatypes.py", line 4433, in _get_child_props
#     if self._props is None:
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\basedatatypes.py", line 4419, in _props
#     return self.parent._get_child_props(self)
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\basedatatypes.py", line 4453, in _get_child_props
#     child_ind = BaseFigure._index_is(children, child)
#   File "C:\Users\wanda\anaconda3\lib\site-packages\plotly\basedatatypes.py", line 3951, in _index_is
#     raise ValueError("Invalid value")
# ValueError: Invalid value
# 127.0.0.1 - - [14/Jun/2023 15:39:57] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [14/Jun/2023 15:39:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:39:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:00] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Jun/2023 15:40:12] "POST /_dash-update-component HTTP/1.1" 200 -
