# %%
pip install dash
pip install plotly
pip install pandas

# %%
#Aufgabe 3
import pandas as pd
import plotly.express as px

#path
path = "C:\\Users\\wanda\\01_Dashboard_Design\\Goal5.5.2_csv.csv"

import dash
from dash import dcc, html
from dash.dependencies import Input, Output

# for later: app = dash.Dash(__name__)

datafile = pd.read_csv(path)

print(datafile.head)
# Out:
# <bound method NDFrame.head of       Goal  Target Indicator   SeriesCode  \
# 0        5     5.5     5.5.2  IC_GEN_MGTL
# 1        5     5.5     5.5.2  IC_GEN_MGTL
# 2        5     5.5     5.5.2  IC_GEN_MGTL
# 3        5     5.5     5.5.2  IC_GEN_MGTL
# 4        5     5.5     5.5.2  IC_GEN_MGTL
# ...    ...     ...       ...          ...
# 4267     5     5.5     5.5.2  IC_GEN_MGTN
# 4268     5     5.5     5.5.2  IC_GEN_MGTN
# 4269     5     5.5     5.5.2  IC_GEN_MGTN
# 4270     5     5.5     5.5.2  IC_GEN_MGTN
# 4271     5     5.5     5.5.2  IC_GEN_MGTN
#
#                                       SeriesDescription  GeoAreaCode  \
# 0       Proportion of women in managerial positions (%)            1
# 1       Proportion of women in managerial positions (%)            1
# 2       Proportion of women in managerial positions (%)            1
# 3       Proportion of women in managerial positions (%)            1
# 4       Proportion of women in managerial positions (%)            1
# ...                                                 ...          ...
# 4267  Proportion of women in senior and middle manag...          882
# 4268  Proportion of women in senior and middle manag...          887
# 4269  Proportion of women in senior and middle manag...          894
# 4270  Proportion of women in senior and middle manag...          894
# 4271  Proportion of women in senior and middle manag...          894
#
#      GeoAreaName  TimePeriod  Value  Time_Detail  ...  Unnamed: 42  \
# 0          World        2000  25.32         2000  ...          NaN
# 1          World        2001  25.67         2001  ...          NaN
# 2          World        2002  25.82         2002  ...          NaN
# 3          World        2003  26.30         2003  ...          NaN
# 4          World        2004  26.35         2004  ...          NaN
# ...          ...         ...    ...          ...  ...          ...
# 4267       Samoa        2017  43.00         2017  ...          NaN
# 4268       Yemen        2014   4.50         2014  ...          NaN
# 4269      Zambia        2017  28.50         2017  ...          NaN
# 4270      Zambia        2018  40.30         2018  ...          NaN
# 4271      Zambia        2019  30.00         2019  ...          NaN
#
#       Unnamed: 43  Unnamed: 44  Unnamed: 45 Unnamed: 46  Unnamed: 47  \
# 0             NaN          NaN          NaN         NaN          NaN
# 1             NaN          NaN          NaN         NaN          NaN
# 2             NaN          NaN          NaN         NaN          NaN
# 3             NaN          NaN          NaN         NaN          NaN
# 4             NaN          NaN          NaN         NaN          NaN
# ...           ...          ...          ...         ...          ...
# 4267          NaN          NaN          NaN         NaN          NaN
# 4268          NaN          NaN          NaN         NaN          NaN
# 4269          NaN          NaN          NaN         NaN          NaN
# 4270          NaN          NaN          NaN         NaN          NaN
# 4271          NaN          NaN          NaN         NaN          NaN
#
#      Unnamed: 48  Unnamed: 49  Unnamed: 50 Unnamed: 51
# 0            NaN          NaN          NaN         NaN
# 1            NaN          NaN          NaN         NaN
# 2            NaN          NaN          NaN         NaN
# 3            NaN          NaN          NaN         NaN
# 4            NaN          NaN          NaN         NaN
# ...          ...          ...          ...         ...
# 4267         NaN          NaN          NaN         NaN
# 4268         NaN          NaN          NaN         NaN
# 4269         NaN          NaN          NaN         NaN
# 4270         NaN          NaN          NaN         NaN
# 4271         NaN          NaN          NaN         NaN
#
# [4272 rows x 52 columns]>

# %%
#Aufgabe 3
import pandas as pd
import plotly.express as px

#Dateipfad
path = "C:\\Users\\wanda\\01_Dashboard_Design\\Goal5.5.2_csv.csv"

#Import
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

app = dash.Dash(__name__)

datafile = pd.read_csv(path)

#Content von Datensatz ausgeben
#print(datafile.head)

app.layout = html.Div([
    
    html.H1("Proportion of women in managerial positions", style = {'text-align': 'center'}),
    html.H4("Numbers and facts about women in managerial positions in the world", style = {'text-align': 'left'}),

])

if __name__ == '__main__':
    app.run_server(debug=False)

# %%
#Aufgabe 3

#Import
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

#Dateipfad
path = "C:\\Users\\wanda\\01_Dashboard_Design\\Goal5.5.2_csv.csv"

#Daten aus CSV-Datei laden
datafile = pd.read_csv(path)

#Balkendiagramm erstellen
fig = px.bar(datafile, x='GeoAreaName', y='Value')

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Proportion of women in managerial positions", style={'text-align': 'center'}),
    html.H4("Numbers and facts about women in managerial positions in the world", style={'text-align': 'left'}),
    dcc.Graph(figure=fig)
])

if __name__ == '__main__':
    app.run_server(debug=False)
